# %%
# Convert CSV to Pandas DataFrame
import pandas as pd

raptors_regularseason_df = pd.read_csv('raptors_regularseason.csv')
raptors_postseason_df = pd.read_csv('raptors_postseason.csv')
cavaliers_regularseason_df = pd.read_csv('cavaliers_regularseason.csv')
cavaliers_postseason_df = pd.read_csv('cavaliers_postseason.csv')
kyrie_irving_df = pd.read_csv('kyrie_irving_df.csv')
lebron_james_df = pd.read_csv('lebron_james_df.csv')
kyle_lowry_df = pd.read_csv('kyle_lowry.csv')
demar_derozan_df = pd.read_csv('demar_derozan.csv')

# %%
raptors_postseason_df.head()
# Out:
#       id        date  home_team_score  period  postseason  season status  \
# 0  33748  2016-04-16               90       4        True    2015  Final
# 1  33750  2016-04-18               98       4        True    2015  Final
# 2  33880  2016-04-21               85       4        True    2015  Final
# 3  33755  2016-04-23              100       4        True    2015  Final
# 4  33885  2016-04-26              102       4        True    2015  Final
#
#    visitor_team_score  home_team.id home_team.abbreviation  ...  \
# 0                 100            28                    TOR  ...
# 1                  87            28                    TOR  ...
# 2                 101            12                    IND  ...
# 3                  83            12                    IND  ...
# 4                  99            28                    TOR  ...
#
#   visitor_team.id visitor_team.abbreviation visitor_team.city  \
# 0              12                       IND           Indiana
# ...

# %%
raptors_regularseason_df
# Out:
#         id        date  home_team_score  period  postseason  season status  \
# 0    27820  2015-10-28              106       4       False    2015  Final
# 1    27689  2015-10-30              103       4       False    2015  Final
# 2    28885  2015-11-01              106       4       False    2015  Final
# 3    29251  2015-11-03               91       4       False    2015  Final
# 4    31100  2015-11-04               98       4       False    2015  Final
# ..     ...         ...              ...     ...         ...     ...    ...
# 241  34532  2018-04-04               96       4       False    2017  Final
# 242  33275  2018-04-06               92       4       False    2017  Final
# 243  34954  2018-04-08              112       4       False    2017  Final
# 244  33025  2018-04-09               98       4       False    2017  Final
# 245  35631  2018-04-11              116       4       False    2017  Final
#
#      visitor_team_score  home_team.id home_team.abbreviation  ...  \
# ...

# %%
cavaliers_regularseason_df
# Out:
#         id        date  home_team_score  period  postseason  season status  \
# 0    31090  2015-10-27               97       4       False    2015  Final
# 1    31093  2015-10-28               76       4       False    2015  Final
# 2    28882  2015-10-30              102       4       False    2015  Final
# 3    28664  2015-11-02              100       4       False    2015  Final
# 4    28666  2015-11-04               96       4       False    2015  Final
# ..     ...         ...              ...     ...         ...     ...    ...
# 241  34530  2018-04-03              112       4       False    2017  Final
# 242  34534  2018-04-05              119       4       False    2017  Final
# 243  33713  2018-04-06              132       4       False    2017  Final
# 244  34955  2018-04-09              109       4       False    2017  Final
# 245  34958  2018-04-11               98       4       False    2017  Final
#
#      visitor_team_score  home_team.id home_team.abbreviation  ...  \
# ...

# %%
cavaliers_postseason_df
# Out:
#        id        date  home_team_score  period  postseason  season status  \
# 0   33876  2016-04-17              106       4        True    2015  Final
# 1   33879  2016-04-20              107       4        True    2015  Final
# 2   33881  2016-04-22               91       4        True    2015  Final
# 3   33883  2016-04-24               98       4        True    2015  Final
# 4   34016  2016-05-02              104       4        True    2015  Final
# ..    ...         ...              ...     ...         ...     ...    ...
# 56  33301  2018-05-27               79       4        True    2017  Final
# 57  33719  2018-05-31              124       4        True    2017  Final
# 58  33720  2018-06-03              122       4        True    2017  Final
# 59  33721  2018-06-06              102       4        True    2017  Final
# 60  33722  2018-06-08               85       4        True    2017  Final
#
#     visitor_team_score  home_team.id home_team.abbreviation  ...  \
# ...

# %%
kyrie_irving_df
# Out:
#         id        date  ast  blk  dreb  fg3_pct  fg3a  fg3m  fg_pct   fga  \
# 0    29073  2015-12-20  4.0  0.0   1.0    1.000   2.0   2.0   0.417  12.0
# 1    32023  2015-12-23  4.0  0.0   0.0    0.000   1.0   0.0   0.143   7.0
# 2    27417  2015-12-25  2.0  0.0   0.0    0.000   6.0   0.0   0.267  15.0
# 3    27419  2015-12-28  2.0  0.0   1.0    0.286   7.0   2.0   0.438  16.0
# 4    28204  2016-01-02  5.0  0.0   1.0    0.000   4.0   0.0   0.333  12.0
# ..     ...         ...  ...  ...   ...      ...   ...   ...     ...   ...
# 219  35600  2018-02-26  5.0  0.0   6.0    0.625   8.0   5.0   0.615  13.0
# 220  34787  2018-02-28  5.0  0.0   3.0    0.667   6.0   4.0   0.722  18.0
# 221  33598  2018-03-03  6.0  0.0   3.0    0.286   7.0   2.0   0.353  17.0
# 222  34493  2018-03-08  8.0  1.0   6.0    0.429   7.0   3.0   0.600  15.0
# 223  34913  2018-03-11  1.0  0.0   3.0    0.333   3.0   1.0   0.500   6.0
#
#      ...  fta  ftm    min  oreb   pf   pts  reb  stl  turnover  total_min
# ...

# %%
lebron_james_df
# Out:
#         id        date   ast  blk  dreb  fg3_pct  fg3a  fg3m  fg_pct   fga  \
# 0    31090  2015-10-27   5.0  0.0  10.0    0.200   5.0   1.0   0.545  22.0
# 1    31093  2015-10-28   5.0  0.0   6.0    0.000   3.0   0.0   0.308  13.0
# 2    28882  2015-10-30   4.0  0.0   3.0    0.000   2.0   0.0   0.684  19.0
# 3    28664  2015-11-02  11.0  2.0   9.0    0.000   3.0   0.0   0.474  19.0
# 4    28666  2015-11-04   3.0  1.0   3.0    0.200   5.0   1.0   0.391  23.0
# ..     ...         ...   ...  ...   ...      ...   ...   ...     ...   ...
# 288  33301  2018-05-27   9.0  2.0  15.0    0.375   8.0   3.0   0.500  24.0
# 289  33719  2018-05-31   8.0  1.0   4.0    0.429   7.0   3.0   0.594  32.0
# 290  33720  2018-06-03  13.0  0.0   8.0    0.500   4.0   2.0   0.500  20.0
# 291  33721  2018-06-06  11.0  2.0   7.0    0.167   6.0   1.0   0.464  28.0
# 292  33722  2018-06-08   8.0  1.0   6.0    0.000   1.0   0.0   0.538  13.0
#
# ...

# %%
kyle_lowry_df
# Out:
#         id        date   ast  blk  dreb  fg3_pct  fg3a  fg3m  fg_pct   fga  \
# 0    27820  2015-10-28   6.0  0.0   2.0    0.500   4.0   2.0   0.471  17.0
# 1    27689  2015-10-30   9.0  2.0   6.0    0.000   1.0   0.0   0.273  11.0
# 2    28885  2015-11-01   7.0  0.0   3.0    0.200   5.0   1.0   0.500  10.0
# 3    29251  2015-11-03  10.0  2.0   5.0    0.800   5.0   4.0   0.600  15.0
# 4    31100  2015-11-04   1.0  0.0   4.0    0.375   8.0   3.0   0.357  14.0
# ..     ...         ...   ...  ...   ...      ...   ...   ...     ...   ...
# 248  34808  2018-04-27   6.0  0.0   5.0    0.429   7.0   3.0   0.600  15.0
# 249  35639  2018-05-01  10.0  0.0   3.0    0.500   6.0   3.0   0.500  12.0
# 250  33043  2018-05-03   8.0  0.0   4.0    0.500   6.0   3.0   0.700  10.0
# 251  33047  2018-05-05   7.0  0.0   3.0    0.500   8.0   4.0   0.692  13.0
# 252  33051  2018-05-07  10.0  0.0   4.0    0.250   4.0   1.0   0.286   7.0
#
# ...

# %%
demar_derozan_df
# Out:
#         id        date  ast  blk  dreb  fg3_pct  fg3a  fg3m  fg_pct   fga  \
# 0    27820  2015-10-28  6.0  0.0   5.0     0.50   2.0   1.0   0.412  17.0
# 1    27689  2015-10-30  6.0  0.0   6.0     0.25   4.0   1.0   0.333  15.0
# 2    28885  2015-11-01  4.0  1.0   1.0     0.00   1.0   0.0   0.538  13.0
# 3    29251  2015-11-03  2.0  0.0   3.0     0.00   0.0   0.0   0.462  13.0
# 4    31100  2015-11-04  3.0  0.0   4.0     0.00   0.0   0.0   0.389  18.0
# ..     ...         ...  ...  ...   ...      ...   ...   ...     ...   ...
# 267  34808  2018-04-27  4.0  0.0   2.0     0.00   4.0   0.0   0.333  18.0
# 268  35639  2018-05-01  5.0  3.0   6.0     0.00   4.0   0.0   0.500  20.0
# 269  33043  2018-05-03  3.0  0.0   0.0     0.00   5.0   0.0   0.478  23.0
# 270  33047  2018-05-05  2.0  2.0   3.0     0.00   0.0   0.0   0.250  12.0
# 271  33051  2018-05-07  1.0  0.0   4.0     0.00   0.0   0.0   0.455  11.0
#
#      ...   fta   ftm    min  oreb   pf   pts  reb  stl  turnover  total_min
# ...

# %%
# Join Lebron James and Cavaliers Regular Season and postseason with date
lebron_james_regularseason_df = pd.merge(lebron_james_df, cavaliers_regularseason_df, on='date')
lebron_james_postseason_df = pd.merge(lebron_james_df, cavaliers_postseason_df, on='date')
lebron_james_regularseason_df
# Out:
#       id_x        date   ast  blk  dreb  fg3_pct  fg3a  fg3m  fg_pct   fga  \
# 0    31090  2015-10-27   5.0  0.0  10.0    0.200   5.0   1.0   0.545  22.0
# 1    31093  2015-10-28   5.0  0.0   6.0    0.000   3.0   0.0   0.308  13.0
# 2    28882  2015-10-30   4.0  0.0   3.0    0.000   2.0   0.0   0.684  19.0
# 3    28664  2015-11-02  11.0  2.0   9.0    0.000   3.0   0.0   0.474  19.0
# 4    28666  2015-11-04   3.0  1.0   3.0    0.200   5.0   1.0   0.391  23.0
# ..     ...         ...   ...  ...   ...      ...   ...   ...     ...   ...
# 227  34530  2018-04-03   6.0  0.0  10.0    0.500   6.0   3.0   0.571  14.0
# 228  34534  2018-04-05  14.0  0.0   7.0    0.286   7.0   2.0   0.600  20.0
# 229  33713  2018-04-06  11.0  1.0  10.0    0.500   8.0   4.0   0.586  29.0
# 230  34955  2018-04-09  11.0  0.0   6.0    0.500   6.0   3.0   0.438  16.0
# 231  34958  2018-04-11   2.0  0.0   4.0    0.000   2.0   0.0   0.444   9.0
#
# ...

# %%
lebron_james_postseason_df
# Out:
#      id_x        date   ast  blk  dreb  fg3_pct  fg3a  fg3m  fg_pct   fga  \
# 0   33876  2016-04-17  11.0  2.0   5.0    0.000   3.0   0.0   0.529  17.0
# 1   33879  2016-04-20   3.0  0.0   5.0    0.500   4.0   2.0   0.667  18.0
# 2   33881  2016-04-22   7.0  1.0  12.0    0.167   6.0   1.0   0.333  24.0
# 3   33883  2016-04-24   6.0  0.0   9.0    0.167   6.0   1.0   0.474  19.0
# 4   34016  2016-05-02   9.0  1.0   7.0    0.500   4.0   2.0   0.524  21.0
# ..    ...         ...   ...  ...   ...      ...   ...   ...     ...   ...
# 56  33301  2018-05-27   9.0  2.0  15.0    0.375   8.0   3.0   0.500  24.0
# 57  33719  2018-05-31   8.0  1.0   4.0    0.429   7.0   3.0   0.594  32.0
# 58  33720  2018-06-03  13.0  0.0   8.0    0.500   4.0   2.0   0.500  20.0
# 59  33721  2018-06-06  11.0  2.0   7.0    0.167   6.0   1.0   0.464  28.0
# 60  33722  2018-06-08   8.0  1.0   6.0    0.000   1.0   0.0   0.538  13.0
#
#     ...  visitor_team.id  visitor_team.abbreviation  visitor_team.city  \
# ...

# %%
# Join Kyrie Irving and Cavaliers Regular Season / postseason with date
kyrie_irving_regularseason_df = pd.merge(kyrie_irving_df, cavaliers_regularseason_df, on='date')
kyrie_irving_postseason_df = pd.merge(kyrie_irving_df, cavaliers_postseason_df, on='date')
kyrie_irving_regularseason_df
# Out:
#       id_x        date  ast  blk  dreb  fg3_pct  fg3a  fg3m  fg_pct   fga  \
# 0    29073  2015-12-20  4.0  0.0   1.0    1.000   2.0   2.0   0.417  12.0
# 1    32023  2015-12-23  4.0  0.0   0.0    0.000   1.0   0.0   0.143   7.0
# 2    27417  2015-12-25  2.0  0.0   0.0    0.000   6.0   0.0   0.267  15.0
# 3    27419  2015-12-28  2.0  0.0   1.0    0.286   7.0   2.0   0.438  16.0
# 4    28204  2016-01-02  5.0  0.0   1.0    0.000   4.0   0.0   0.333  12.0
# ..     ...         ...  ...  ...   ...      ...   ...   ...     ...   ...
# 150  35228  2018-02-09  5.0  0.0   1.0    0.286   7.0   2.0   0.444  18.0
# 151  35594  2018-02-11  5.0  0.0   3.0    0.143   7.0   1.0   0.500  14.0
# 152  34784  2018-02-23  6.0  0.0   5.0    0.444   9.0   4.0   0.500  14.0
# 153  33598  2018-03-03  6.0  0.0   3.0    0.286   7.0   2.0   0.353  17.0
# 154  34913  2018-03-11  1.0  0.0   3.0    0.333   3.0   1.0   0.500   6.0
#
#      ...  visitor_team.id  visitor_team.abbreviation  visitor_team.city  \
# ...

# %%
# Join Kyle Lowry and Rapters Regular Season by date ( FUll Outer Join)
kyle_lowry_regularseason_df = pd.merge(kyle_lowry_df, raptors_regularseason_df, on='date')

kyle_lowry_regularseason_df
# Out:
#       id_x        date   ast  blk  dreb  fg3_pct  fg3a  fg3m  fg_pct   fga  \
# 0    27820  2015-10-28   6.0  0.0   2.0    0.500   4.0   2.0   0.471  17.0
# 1    27689  2015-10-30   9.0  2.0   6.0    0.000   1.0   0.0   0.273  11.0
# 2    28885  2015-11-01   7.0  0.0   3.0    0.200   5.0   1.0   0.500  10.0
# 3    29251  2015-11-03  10.0  2.0   5.0    0.800   5.0   4.0   0.600  15.0
# 4    31100  2015-11-04   1.0  0.0   4.0    0.375   8.0   3.0   0.357  14.0
# ..     ...         ...   ...  ...   ...      ...   ...   ...     ...   ...
# 210  34532  2018-04-04   5.0  1.0   4.0    0.286   7.0   2.0   0.455  11.0
# 211  33275  2018-04-06   9.0  2.0   5.0    0.375   8.0   3.0   0.273  11.0
# 212  34954  2018-04-08   7.0  0.0   1.0    0.143   7.0   1.0   0.300  10.0
# 213  33025  2018-04-09   9.0  1.0   6.0    0.429   7.0   3.0   0.500   8.0
# 214  35631  2018-04-11   9.0  0.0   9.0    0.500  10.0   5.0   0.500  20.0
#
# ...
